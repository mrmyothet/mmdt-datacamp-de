# %%
import pandas as pd
import requests

# %%
api_url = "https://raw.githubusercontent.com/owid/covid-19-data/refs/heads/master/public/data/latest/owid-covid-latest.json"
response = requests.get(api_url)
raw_data = response.json()

new_df = pd.DataFrame(raw_data)
new_df = new_df.transpose()

assert new_df.shape == (247, 66), "dataframe is incorrect shape"

# %%
df = pd.DataFrame(raw_data)

value = raw_data["MMR"]
value 
df = pd.json_normalize(value)
df

# %%
result_df = pd.DataFrame()

for key in raw_data.keys():
    row = raw_data[key]
    row_df = pd.json_normalize(row)
    row_df['country_code'] = key
    result_df = pd.concat([result_df, row_df], ignore_index=True)

assert result_df.shape == (247, 67), "dataframe is incorrect shape"

# %%
result_df.shape
# Out:
# (247, 67)

# %%
result_df.head()
# Out:
#   continent  ... country_code
# 0      Asia  ...          AFG
# 1      None  ...     OWID_AFR
# 2    Europe  ...          ALB
# 3    Africa  ...          DZA
# 4   Oceania  ...          ASM
#
# [5 rows x 67 columns]

# %%
url_cities = "https://raw.githubusercontent.com/dr5hn/countries-states-cities-database/refs/heads/master/json/countries%2Bcities.json"
response_cities = requests.get(url_cities)

# %%
raw_data_cities = response_cities.json()

df_cities = pd.json_normalize(raw_data_cities)

# %%
df_cities.columns

# %%
df_cities.head()
# Out:
#    id            name  ...     translations.uk     translations.pl
# 0   1     Afghanistan  ...          Афганістан          Afganistan
# 1   2   Aland Islands  ...   Аландські острови     Wyspy Alandzkie
# 2   3         Albania  ...             Албанія             Albania
# 3   4         Algeria  ...               Алжир            Algieria
# 4   5  American Samoa  ...  Американське Самоа  Samoa Amerykańskie
#
# [5 rows x 39 columns]

# %%
df_cities.shape
# Out:
# (250, 39)

# %%
merge_df = result_df.merge(df_cities, left_on="country_code", right_on="iso3")

# %%
lst_capital = merge_df['capital'].unique()
lst_capital.size
# Out:
# 234

# %%
url_countries = "https://raw.githubusercontent.com/dr5hn/countries-states-cities-database/refs/heads/master/json/countries.json"
response_contries = requests.get(url_countries)
raw_data_countries = response_contries.json()
df_countries = pd.json_normalize(raw_data_countries)

# %%
df_countries.shape
df_countries = df_countries[["iso3", "capital"]]

# %%
merge_df = result_df.merge(df_countries, left_on="country_code", right_on="iso3")

# %%
merge_df.shape
# Out:
# (234, 69)

# %%
merge_df.head()
# Out:
#   continent        location  ... iso3           capital
# 0      Asia     Afghanistan  ...  AFG             Kabul
# 1    Europe         Albania  ...  ALB            Tirana
# 2    Africa         Algeria  ...  DZA           Algiers
# 3   Oceania  American Samoa  ...  ASM         Pago Pago
# 4    Europe         Andorra  ...  AND  Andorra la Vella
#
# [5 rows x 69 columns]
